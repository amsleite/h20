# %%
import h2o

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------
# H2O cluster uptime:         1 hour 17 mins
# H2O cluster timezone:       America/Sao_Paulo
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.26.0.3
# H2O cluster version age:    14 days, 13 hours and 57 minutes
# H2O cluster name:           H2O_from_python_Semantix_qmsw3y
# H2O cluster total nodes:    1
# H2O cluster free memory:    3.517 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  8
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         Amazon S3, Algos, AutoML, Core V3, Core V4
# Python version:             3.7.3 final
# --------------------------  ------------------------------------------

# %%
datasets = "https://raw.githubusercontent.com/DarrenCook/h2o/bk/datasets/"

# %%
data = h2o.import_file(datasets + "iris_wheader.csv")
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
y = "class"
x = data.names
x.remove(y)
train, test = data.split_frame([0.8], seed=99)

# %%
m = h2o.estimators.deeplearning.H2ODeepLearningEstimator(seed=99, reproducible=True)

# %%
m.train(x, y, train)
# Out:
# deeplearning Model Build progress: |██████████████████████████████████████| 100%

# %%
p = m.predict(test)
# Out:
# deeplearning prediction progress: |███████████████████████████████████████| 100%

# %%
m.confusion_matrix(train)
# Out:
# Confusion Matrix: Row labels: Actual class; Column labels: Predicted class
#    Iris-setosa  Iris-versicolor  Iris-virginica     Error     Rate
# 0         42.0              0.0             0.0  0.000000   0 / 42
# 1          0.0             37.0             1.0  0.026316   1 / 38
# 2          0.0              1.0            39.0  0.025000   1 / 40
# 3         42.0             38.0            40.0  0.016667  2 / 120

# %%
p.as_data_frame()
# Out:
#             predict   Iris-setosa  Iris-versicolor  Iris-virginica
# 0       Iris-setosa  9.990161e-01         0.000984    1.902827e-19
# 1       Iris-setosa  9.989882e-01         0.001012    1.402089e-20
# 2       Iris-setosa  9.992540e-01         0.000746    9.224657e-19
# 3       Iris-setosa  9.995346e-01         0.000465    1.411897e-18
# 4       Iris-setosa  9.931259e-01         0.006874    4.990024e-16
# 5       Iris-setosa  9.999441e-01         0.000056    4.385715e-21
# 6       Iris-setosa  9.998402e-01         0.000160    8.551177e-21
# 7       Iris-setosa  9.997184e-01         0.000282    3.368577e-18
# 8   Iris-versicolor  5.220345e-05         0.997722    2.225362e-03
# 9   Iris-versicolor  2.751257e-04         0.995354    4.370548e-03
# 10  Iris-versicolor  3.912682e-05         0.980511    1.945032e-02
# 11  Iris-versicolor  4.410285e-04         0.999540    1.863251e-05
# 12   Iris-virginica  4.783990e-07         0.453048    5.469519e-01
# 13  Iris-versicolor  7.294502e-07         0.991363    8.636492e-03
# 14   Iris-virginica  5.180033e-07         0.072899    9.271005e-01
# 15  Iris-versicolor  1.916081e-03         0.908749    8.933470e-02
# 16  Iris-versicolor  8.966037e-04         0.989995    9.108883e-03
# 17  Iris-versicolor  2.600133e-03         0.997035    3.645483e-04
# 18  Iris-versicolor  1.422786e-04         0.999624    2.337230e-04
# 19  Iris-versicolor  6.709899e-03         0.993272    1.810144e-05
# 20   Iris-virginica  1.009727e-08         0.008876    9.911238e-01
# 21   Iris-virginica  5.848128e-08         0.060104    9.398957e-01
# 22   Iris-virginica  2.039842e-08         0.000567    9.994330e-01
# 23   Iris-virginica  7.476746e-12         0.000029    9.999713e-01
# 24   Iris-virginica  2.975610e-12         0.000810    9.991903e-01
# 25   Iris-virginica  2.444083e-09         0.030736    9.692643e-01
# 26   Iris-virginica  6.137816e-14         0.000044    9.999564e-01
# 27   Iris-virginica  6.923318e-11         0.000532    9.994684e-01
# 28   Iris-virginica  1.213130e-12         0.000008    9.999919e-01
# 29   Iris-virginica  1.726174e-11         0.000102    9.998980e-01

# %%
p["predict"].cbind(test["class"]).as_data_frame()
# Out:
#             predict            class
# 0       Iris-setosa      Iris-setosa
# 1       Iris-setosa      Iris-setosa
# 2       Iris-setosa      Iris-setosa
# 3       Iris-setosa      Iris-setosa
# 4       Iris-setosa      Iris-setosa
# 5       Iris-setosa      Iris-setosa
# 6       Iris-setosa      Iris-setosa
# 7       Iris-setosa      Iris-setosa
# 8   Iris-versicolor  Iris-versicolor
# 9   Iris-versicolor  Iris-versicolor
# 10  Iris-versicolor  Iris-versicolor
# 11  Iris-versicolor  Iris-versicolor
# 12   Iris-virginica  Iris-versicolor
# 13  Iris-versicolor  Iris-versicolor
# 14   Iris-virginica  Iris-versicolor
# 15  Iris-versicolor  Iris-versicolor
# 16  Iris-versicolor  Iris-versicolor
# 17  Iris-versicolor  Iris-versicolor
# 18  Iris-versicolor  Iris-versicolor
# 19  Iris-versicolor  Iris-versicolor
# 20   Iris-virginica   Iris-virginica
# 21   Iris-virginica   Iris-virginica
# 22   Iris-virginica   Iris-virginica
# 23   Iris-virginica   Iris-virginica
# 24   Iris-virginica   Iris-virginica
# 25   Iris-virginica   Iris-virginica
# 26   Iris-virginica   Iris-virginica
# 27   Iris-virginica   Iris-virginica
# 28   Iris-virginica   Iris-virginica
# 29   Iris-virginica   Iris-virginica

# %%
# save the model
model_path = h2o.save_model(model=m, path="/tmp/mymodel", force=True)



# load the model
saved_model = h2o.load_model(model_path)

# %%
print (model_path)
# Out:
# C:\tmp\mymodel\DeepLearning_model_python_1567871777231_1
